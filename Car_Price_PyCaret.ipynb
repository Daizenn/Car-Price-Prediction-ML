# %%
import pandas as pd

# %%
df = pd.read_csv('/content/wow.csv')

# %%
df
# Out:
#          brand jenis_mobil  tahun_kendaraan    warna  transmisi  kilometer  \
# 0      Hyundai       Wagon             2022  Lainnya  Automatic      12500
# 1        Tesla       Wagon             2022    Hitam  Automatic        153
# 2        Tesla       Sedan             2020   Silver  Automatic      17500
# 3       Wuling   Hatchback             2022    Putih  Automatic       2500
# 4      Hyundai    Fastback             2020    Hitam  Automatic      87500
# ...        ...         ...              ...      ...        ...        ...
# 10721      BMW         SUV             2018    Putih  Automatic      32500
# 10722  Hyundai   Hatchback             2017   Orange  Automatic      62000
# 10723      BMW         SUV             2018    Hitam  Automatic      17500
# 10724  Hyundai         SUV             2021    Putih  Automatic      17500
# 10725      BMW       Wagon             2018   Kuning  Automatic      17500
#
# ...

# %% [markdown]
# warna_mapping = {
#     'Lainnya': 0, 'Hitam': 1, 'Silver': 2, 'Putih': 3, 'Hijau': 4,
#     'Abu-abu': 5, 'Merah': 6, 'Biru': 7, 'Kuning': 8, 'Emas': 9,
#     'Marun': 10, 'Coklat': 11, 'Orange': 12, 'Ungu': 13
# }
#
# bahan_bakar_mapping = {
#     'Electric': 0, 'Pertamax': 1, 'Solar': 2
# }
#
# dirakit_mapping = {
#     'Complete Knock Down (CKD)': 0, 'Complete Built Up (CBU)': 1,
#     'Semi Knock Down (SKD)': 2, '4 Speaker Stereo': 3
# }
#
# daerah_mapping = {
#     'DKI Jakarta': 0, 'Banten': 1, 'Jawa Barat': 2, 'Jawa Timur': 3,
#     'Lampung': 4, 'Jawa Tengah': 5, 'Sumatera Utara': 6, 'Kalimantan Barat': 7,
#     'Sumatera Barat': 8, 'Yogyakarta': 9, 'Bali': 10, 'Sumatera Selatan': 11,
#     'Sulawesi Selatan': 12, 'Kalimantan Timur': 13, 'Jambi': 14
# }
#
# transmisi_mapping = {
#     'Automatic': 0, 'Manual': 1
# }
#
# jenis_mobil_mapping = {
#     'Wagon': 0, 'Sedan': 1, 'Hatchback': 2, 'Fastback': 3, 'Coupe': 4,
#     'SUV': 5, 'MPV': 6, 'Convertible': 7, 'Van': 8, 'Pick-up': 9,
#     'Cabriolet': 10, 'Targa': 11, 'Double Cabin': 12, 'Jeep': 13,
#     'Box': 14, 'Minibus': 15
# }
#
# brand_mapping = {
#     'Hyundai': 0, 'Tesla': 1, 'Wuling': 2, 'Porsche': 3, 'KIA': 4, 'Lexus': 5, 'BMW': 6, 'Toyota': 7,
#     'Nissan': 8, 'Mercedes-Benz': 9, 'Chery': 10, 'Volkswagen': 11, 'MINI': 12, 'Ford': 13, 'Honda': 14,
#     'Mitsubishi': 15, 'Chevrolet': 16, 'Land Rover': 17, 'Mazda': 18, 'Daihatsu': 19, 'Suzuki': 20,
#     'Peugeot': 21, 'Jeep': 22, 'Proton': 23, 'Geely': 24, 'Isuzu': 25, 'MG': 26, 'smart': 27, 'Audi': 28,
#     'Maserati': 29, 'Cadillac': 30, 'Rolls-Royce': 31, 'Bentley': 32, 'Hummer': 33, 'Renault': 34,
#     'DFSK': 35, 'Subaru': 36, 'Aston Martin': 37
# }

# %%
pip install pycaret

# %%
df
# Out:
#          brand jenis_mobil  tahun_kendaraan    warna  transmisi  kilometer  \
# 0      Hyundai       Wagon             2022  Lainnya  Automatic      12500
# 1        Tesla       Wagon             2022    Hitam  Automatic        153
# 2        Tesla       Sedan             2020   Silver  Automatic      17500
# 3       Wuling   Hatchback             2022    Putih  Automatic       2500
# 4      Hyundai    Fastback             2020    Hitam  Automatic      87500
# ...        ...         ...              ...      ...        ...        ...
# 10721      BMW         SUV             2018    Putih  Automatic      32500
# 10722  Hyundai   Hatchback             2017   Orange  Automatic      62000
# 10723      BMW         SUV             2018    Hitam  Automatic      17500
# 10724  Hyundai         SUV             2021    Putih  Automatic      17500
# 10725      BMW       Wagon             2018   Kuning  Automatic      17500
#
# ...

# %%
from pycaret.regression import *
s = setup(df, target = 'harga', session_id = 123)
# Out:
# <style type="text/css">
# #T_aab58_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_aab58" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aab58_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_aab58_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aab58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aab58_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_aab58_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_aab58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aab58_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_aab58_row1_col1" class="data row1 col1" >harga</td>
#     </tr>
#     <tr>
#       <th id="T_aab58_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# functional API
best = compare_models()
# Out:
# <style type="text/css">
# #T_4db6a th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# ExtraTreesRegressor(n_jobs=-1, random_state=123)

# %%
# functional API
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# functional API
plot_model(best, plot = 'residuals')

# %%
# functional API
plot_model(best, plot = 'feature')

# %%
# functional API
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9be7d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9be7d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9be7d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_9be7d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_9be7d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_9be7d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_9be7d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_9be7d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9be7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9be7d_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_9be7d_row0_col1" class="data row0 col1" >27273527.0735</td>
# ...

# %%
# functional API
predictions = predict_model(best, data=df)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_70199" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70199_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_70199_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_70199_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_70199_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_70199_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_70199_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_70199_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70199_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70199_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_70199_row0_col1" class="data row0 col1" >10226042.2280</td>
# ...

# %%
# functional API
save_model(best, 'my_best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['tahun_kendaraan', 'kilometer',
#                                               'mesin_enginecc', 'penumpang',
#                                               'pintu'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['brand', 'jenis_mobil', 'warna',
#                                               'transmisi', 'bahan_bakar',
#                                               'dirakit'],
#                                      transformer=SimpleImputer(strategy='most...
#                   TransformerWrapper(include=['jenis_mobil', 'warna',
#                                               'bahan_bakar', 'dirakit'],
# ...

# %%
# functional API
loaded_model = load_model('my_best_pipeline')
print(loaded_model)
